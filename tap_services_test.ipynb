# %% [markdown]
# <h2>Utilities for testing TAP services</h2>

# %%
from lsst.rsp import get_tap_service
from IPython.display import display, HTML

import sys

def print_test(msg, color="black", file = None):
    display(HTML(f'<span style="color: {color}">{msg.replace(" ", "&nbsp;")}</span>'))
    if file:
        file.write(msg + '\n')

def print_error(msg, object_name, exception, query = None, file = None):
    err_msg = f"Error {msg}: {object_name}"
    display(HTML(f'<span style="color: red; font-weight: bold;">{err_msg}</span>'))
    display(HTML(f'<span style="color: red;">{exception}</span>'))
    if file:
        file.write(err_msg + '\n')
        if query:
            file.write(query + '\n')
        file.write(str(exception) + '\n')
        file.write('\n')

def test_tap_services(tap_services = ["tap", "ssotap", "consdbtap"], check_single_columns = False, log_file = None, only_print_errors = False):
    schema_query = 'SELECT * FROM tap_schema.schemas'
    for tap_service_name in tap_services:
        if not only_print_errors:
            print_test(f"Testing TAP service: {tap_service_name}", file = log_file)
        try:
            service = get_tap_service(tap_service_name)
        except Exception as e1:
            print_error("getting TAP service", tap_service_name, e1, file = log_file)
            continue
        try:
            schema_results_table = service.search(schema_query).to_table()
        except Exception as e2:
            print_error("fetching schemas for", tap_service_name, e2, file = log_file)
            continue
        for schema_name in schema_results_table['schema_name']:
            table_query = f"SELECT * FROM tap_schema.tables WHERE tap_schema.tables.schema_name = '{schema_name}' ORDER BY table_index ASC"
            try:
                table_results_table = service.search(table_query).to_table()
            except Exception as e3:
                print_error("getting tables for", schema_name, e3, file = log_file)
            for table_name in sorted(table_results_table["table_name"]):
                if not table_name.startswith("tap_schema."):
                    if not only_print_errors:
                        print_test(f"Testing table: {table_name}", file = log_file)
                    test_query = f'SELECT * FROM {table_name} LIMIT 1'
                    if not only_print_errors:
                        print_test(test_query, file = log_file)
                    try:
                        test_results_table = service.search(test_query).to_table()
                        if not only_print_errors:
                            print_test(f"Successfully got {len(test_results_table)} record(s) from {table_name}", color="green", file = log_file) 
                    except Exception as e4:
                        print_error("selecting records from", table_name, e4, file = log_file)
                    if check_single_columns:
                        columns_query = f"SELECT * FROM tap_schema.columns WHERE table_name = '{table_name}'"
                        if not only_print_errors:
                            print_test(columns_query)
                        columns_result = service.search(columns_query).to_table()
                        sorted_column_list = sorted(columns_result["column_name"])
                        if not only_print_errors:
                            print_test("Column list:", file = log_file)
                        for column_name in sorted_column_list:
                            if not only_print_errors:
                                print_test(f"    {column_name}", file = log_file)  
                        for column_name in sorted_column_list:
                            if not only_print_errors:
                                print_test(f"Checking single column: {table_name}.{column_name}", file = log_file)
                            single_column_query = f'SELECT "{column_name}" from {table_name} LIMIT 1'
                            if not only_print_errors:
                                print_test(single_column_query, file = log_file)
                            try:
                                single_column_results_table = service.search(single_column_query).to_table()
                                if not only_print_errors:
                                    print_test(f"Successfully got results for single column: {table_name}.{column_name}", color="green", file = log_file)
                            except Exception as e5:
                                print_error("getting results for column", f"{table_name}.{column_name}", e5, query = single_column_query, file = log_file)
                                continue
        print_test("Done checking TAP services!")

# %% [markdown]
# <h2>All TAP services</h2>

# %%
# , "livetap",
test_tap_services(["tap", "consdbtap"])
# Out:
# <span style="color: black">Testing&nbsp;TAP&nbsp;service:&nbsp;tap</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.CcdVisit</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.CcdVisit&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.CcdVisit</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.CoaddPatches</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.CoaddPatches&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.CoaddPatches</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.DiaObject</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.DiaObject&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.DiaObject</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.DiaSource</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.DiaSource&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.DiaSource</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.ForcedSource</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.ForcedSource&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.ForcedSource</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.ForcedSourceOnDiaObject</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.ForcedSourceOnDiaObject&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.ForcedSourceOnDiaObject</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.MatchesTruth</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.MatchesTruth&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.MatchesTruth</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.Object</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.Object&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.Object</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.Source</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.Source&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.Source</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.TruthSummary</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.TruthSummary&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.TruthSummary</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;dp02_dc2_catalogs.Visit</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;dp02_dc2_catalogs.Visit&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;dp02_dc2_catalogs.Visit</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;ivoa.ObsCore</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;ivoa.ObsCore&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;ivoa.ObsCore</span>
# <span style="color: black">Done&nbsp;checking&nbsp;TAP&nbsp;services!</span>
# <span style="color: black">Testing&nbsp;TAP&nbsp;service:&nbsp;consdbtap</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.ccdexposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.ccdexposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.ccdexposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.ccdexposure_camera</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.ccdexposure_camera&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.ccdexposure_camera</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.ccdexposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.ccdexposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.ccdexposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.ccdexposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.ccdexposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.ccdexposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.ccdvisit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.ccdvisit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.ccdvisit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.ccdvisit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.ccdvisit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.ccdvisit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.exposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.exposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.exposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.exposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.exposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.exposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.exposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.exposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.exposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.exposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.exposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.exposure_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.visit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.visit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.visit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_latiss.visit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_latiss.visit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_latiss.visit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.ccdexposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.ccdexposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.ccdexposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.ccdexposure_camera</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.ccdexposure_camera&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.ccdexposure_camera</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.ccdexposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.ccdexposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.ccdexposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.ccdexposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.ccdexposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.ccdexposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.ccdexposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.ccdexposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.ccdexposure_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.ccdvisit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.ccdvisit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.ccdvisit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.ccdvisit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.ccdvisit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.ccdvisit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.exposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.exposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.exposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.exposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.exposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.exposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.exposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.exposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.exposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.exposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.exposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.exposure_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.visit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.visit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.visit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcam.visit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcam.visit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcam.visit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.ccdexposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.ccdexposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.ccdexposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.ccdexposure_camera</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.ccdexposure_camera&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.ccdexposure_camera</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.ccdexposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.ccdexposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.ccdexposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.ccdexposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.ccdexposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.ccdexposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.ccdexposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.ccdexposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.ccdexposure_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.ccdvisit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.ccdvisit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.ccdvisit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.ccdvisit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.ccdvisit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.ccdvisit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.exposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.exposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.exposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.exposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.exposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.exposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.exposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.exposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.exposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.exposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.exposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.exposure_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.visit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.visit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.visit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcam.visit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcam.visit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcam.visit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.ccdexposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.ccdexposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.ccdexposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.ccdexposure_camera</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.ccdexposure_camera&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.ccdexposure_camera</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.ccdexposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.ccdexposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.ccdexposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.ccdexposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.ccdexposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.ccdexposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.ccdvisit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.ccdvisit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.ccdvisit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.ccdvisit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.ccdvisit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.ccdvisit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.exposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.exposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.exposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.exposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.exposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.exposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.exposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.exposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.exposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.visit1</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.visit1&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.visit1</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_lsstcomcamsim.visit1_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_lsstcomcamsim.visit1_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;1&nbsp;record(s)&nbsp;from&nbsp;cdb_lsstcomcamsim.visit1_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerfast.exposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerfast.exposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerfast.exposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerfast.exposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerfast.exposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerfast.exposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerfast.exposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerfast.exposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerfast.exposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerfast.exposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerfast.exposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerfast.exposure_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackernarrow.exposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackernarrow.exposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackernarrow.exposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackernarrow.exposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackernarrow.exposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackernarrow.exposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackernarrow.exposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackernarrow.exposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackernarrow.exposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackernarrow.exposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackernarrow.exposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackernarrow.exposure_quicklook</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerwide.exposure</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerwide.exposure&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerwide.exposure</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerwide.exposure_flexdata</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerwide.exposure_flexdata&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerwide.exposure_flexdata</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerwide.exposure_flexdata_schema</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerwide.exposure_flexdata_schema&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerwide.exposure_flexdata_schema</span>
# <span style="color: black">Testing&nbsp;table:&nbsp;cdb_startrackerwide.exposure_quicklook</span>
# <span style="color: black">SELECT&nbsp;*&nbsp;FROM&nbsp;cdb_startrackerwide.exposure_quicklook&nbsp;LIMIT&nbsp;1</span>
# <span style="color: green">Successfully&nbsp;got&nbsp;0&nbsp;record(s)&nbsp;from&nbsp;cdb_startrackerwide.exposure_quicklook</span>
# <span style="color: black">Done&nbsp;checking&nbsp;TAP&nbsp;services!</span>

# %% [markdown]
# <h2>consdbtap</h2>

# %%
with open("consdbtap_test.txt", 'w') as f:
    test_tap_services(["consdbtap"], check_single_columns=True, log_file = f)

# %% [markdown]
# <h2>Debugging junk below here</h2>

# %%
# test_tap_services()

# %%
# Query for browser:
# https://usdf-rsp-int.slac.stanford.edu/api/consdbtap/sync?LANG=ADQL&REQUEST=doQuery&QUERY=SELECT+*+FROM+cdb_latiss.visit1+LIMIT+1

# %%
# service = get_tap_service("consdbtap")
# results = service.search("SELECT * FROM cdb_latiss.visit1_quicklook").to_table()
# results

# %%
service = get_tap_service("consdbtap")
type(service)
# Out:
# pyvo.dal.tap.TAPService

# %%
service.search("SELECT s_region from cdb_lsstcomcamsim.ccdvisit1")
# Out:
# <DALResultsTable length=58221>
# s_region
# str1024
# --------
#
#
#
#
#
#
#
#
#
#      ...

# %%
# test of transaction issue
service = get_tap_service("consdbtap")

schema_results_table = service.search('SELECT * FROM tap_schema.schemas').to_table()
for schema_name in schema_results_table['schema_name']:
    table_query = f"SELECT * FROM tap_schema.tables WHERE tap_schema.tables.schema_name = '{schema_name}' ORDER BY table_name ASC"
    table_results = service.search(table_query).to_table()
    for table_name in table_results["table_name"]:
        if not table_name.startswith("tap_schema."):
            select_all_query = f'SELECT * FROM {table_name} LIMIT 1'
            try:
                service.search(select_all_query)
            except Exception as e:
                print(select_all_query)
                print(e)
                print('\n')
        column_query = f"SELECT * FROM tap_schema.columns WHERE table_name = '{table_name}' ORDER BY table_name ASC"
        column_results = service.search(column_query).to_table()
        for column_name in column_results["column_name"]:
            select_column_query = f'SELECT "{column_name}" from {table_name} LIMIT 1'
            try:
                service.search(select_column_query)
            except Exception as e:
                print(select_column_query)
                print(e)
                print('\n')

# %%
schema_results_table = get_tap_service("consdbtap").search('SELECT * FROM tap_schema.schemas').to_table()
for schema_name in schema_results_table['schema_name']:
    table_query = f"SELECT * FROM tap_schema.tables WHERE tap_schema.tables.schema_name = '{schema_name}' ORDER BY table_name ASC"
    table_results = get_tap_service("consdbtap").search(table_query).to_table()
    for table_name in table_results["table_name"]:
        if not table_name.startswith("tap_schema."):
            column_query = f"SELECT * FROM tap_schema.columns WHERE table_name = '{table_name}' ORDER BY table_name ASC"
            column_results = service.search(column_query).to_table()
            for column_name in column_results["column_name"]:
                select_column_query = f'SELECT "{column_name}" from {table_name} LIMIT 1'
                try:
                    get_tap_service("consdbtap").search(select_column_query)
                except Exception as e:
                    print(select_column_query)
                    print(e)
# Out:
# SELECT "ccdexposure_id" from cdb_lsstcomcamsim.ccdexposure LIMIT 1
# ERROR: permission denied for table ccdexposure
# SELECT "day_obs" from cdb_lsstcomcamsim.ccdexposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "detector" from cdb_lsstcomcamsim.ccdexposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "exposure_id" from cdb_lsstcomcamsim.ccdexposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "s_region" from cdb_lsstcomcamsim.ccdexposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "seq_num" from cdb_lsstcomcamsim.ccdexposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "ccd_temp" from cdb_lsstcomcamsim.ccdexposure_camera LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "ccdexposure_id" from cdb_lsstcomcamsim.ccdexposure_camera LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "temp_set" from cdb_lsstcomcamsim.ccdexposure_camera LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "key" from cdb_lsstcomcamsim.ccdexposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "obs_id" from cdb_lsstcomcamsim.ccdexposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "value" from cdb_lsstcomcamsim.ccdexposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "doc" from cdb_lsstcomcamsim.ccdexposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "dtype" from cdb_lsstcomcamsim.ccdexposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "key" from cdb_lsstcomcamsim.ccdexposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "ucd" from cdb_lsstcomcamsim.ccdexposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "unit" from cdb_lsstcomcamsim.ccdexposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "ccdvisit_id" from cdb_lsstcomcamsim.ccdvisit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "detector" from cdb_lsstcomcamsim.ccdvisit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "s_region" from cdb_lsstcomcamsim.ccdvisit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "visit_id" from cdb_lsstcomcamsim.ccdvisit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "astrom_offset_mean" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "astrom_offset_std" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "ccdvisit_id" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "eff_time" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "eff_time_psf_sigma_scale" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "eff_time_sky_bg_scale" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "eff_time_zero_point_scale" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "max_dist_to_nearest_psf" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "mean_var" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "n_psf_star" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "photometric_calib" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "pixel_scale" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "postisr_pixel_median" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "psf_ap_corr_sigma_scaled_delta" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "psf_ap_flux_delta" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdexposure
# SELECT "psf_area" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_ixx" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_ixy" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_iyy" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_sigma" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_star_delta_e1_median" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_star_delta_e1_scatter" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_star_delta_e2_median" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_star_delta_e2_scatter" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_star_delta_size_median" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_star_delta_size_scatter" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_star_scaled_delta_size_scatter" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "psf_trace_radius_delta" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "s_dec" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "s_ra" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "seeing_zenith_500nm" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "sky_bg" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "sky_noise" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "stats_mag_lim" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "zenith_distance" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "zero_point" from cdb_lsstcomcamsim.ccdvisit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "air_temp" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "airmass" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "altitude" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "altitude_end" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "altitude_start" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "azimuth" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "azimuth_end" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "azimuth_start" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "band" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "controller" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "cur_index" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "dark_time" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "day_obs" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "dimm_seeing" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "emulated" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "exp_midpt" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "exp_midpt_mjd" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "exp_time" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "exposure_id" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "exposure_name" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "focus_z" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "group_id" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "humidity" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "img_type" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "max_index" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "obs_end" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "obs_end_mjd" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "obs_start" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "obs_start_mjd" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "observation_reason" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "physical_filter" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "pressure" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "s_dec" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "s_ra" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "s_region" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "science_program" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "seq_num" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "shut_time" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "simulated" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "sky_rotation" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "target_name" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "vignette" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "vignette_min" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "wind_dir" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "wind_speed" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "zenith_distance" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table ccdvisit1_quicklook
# SELECT "zenith_distance_end" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: permission denied for table exposure
# SELECT "zenith_distance_start" from cdb_lsstcomcamsim.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "day_obs" from cdb_lsstcomcamsim.exposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "key" from cdb_lsstcomcamsim.exposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "obs_id" from cdb_lsstcomcamsim.exposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "seq_num" from cdb_lsstcomcamsim.exposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "value" from cdb_lsstcomcamsim.exposure_flexdata LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "doc" from cdb_lsstcomcamsim.exposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "dtype" from cdb_lsstcomcamsim.exposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "key" from cdb_lsstcomcamsim.exposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "ucd" from cdb_lsstcomcamsim.exposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "unit" from cdb_lsstcomcamsim.exposure_flexdata_schema LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "air_temp" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "airmass" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "altitude" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "altitude_end" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "altitude_start" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "azimuth" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "azimuth_end" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "azimuth_start" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "band" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "controller" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "cur_index" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "dark_time" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "day_obs" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "dimm_seeing" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "emulated" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "exp_midpt" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "exp_midpt_mjd" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "exp_time" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "exposure_name" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "focus_z" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "group_id" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "humidity" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "img_type" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "max_index" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "obs_end" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "obs_end_mjd" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "obs_start" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "obs_start_mjd" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "observation_reason" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "physical_filter" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "pressure" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "s_dec" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "s_ra" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "s_region" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "science_program" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "seq_num" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "shut_time" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "simulated" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "sky_rotation" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "target_name" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "vignette" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "vignette_min" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "visit_id" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "wind_dir" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "wind_speed" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "zenith_distance" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "zenith_distance_end" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "zenith_distance_start" from cdb_lsstcomcamsim.visit1 LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "astrom_offset_mean_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "astrom_offset_mean_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "astrom_offset_mean_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "astrom_offset_std_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table exposure
# SELECT "astrom_offset_std_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: permission denied for table visit1_quicklook
# SELECT "astrom_offset_std_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "day_obs" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_psf_sigma_scale_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_psf_sigma_scale_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_psf_sigma_scale_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_sky_bg_scale_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_sky_bg_scale_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_sky_bg_scale_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_zero_point_scale_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_zero_point_scale_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "eff_time_zero_point_scale_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "high_snr_source_count_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "high_snr_source_count_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "high_snr_source_count_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "high_snr_source_count_total" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "low_snr_source_count_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "low_snr_source_count_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "low_snr_source_count_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "low_snr_source_count_total" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "max_dist_to_nearest_psf_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "max_dist_to_nearest_psf_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "max_dist_to_nearest_psf_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "mean_var_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "mean_var_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "mean_var_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "n_inputs" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "n_psf_star_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "n_psf_star_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "n_psf_star_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "n_psf_star_total" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "pixel_scale_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "pixel_scale_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "pixel_scale_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "postisr_pixel_median_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "postisr_pixel_median_mean" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "postisr_pixel_median_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ap_corr_sigma_scaled_delta_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ap_corr_sigma_scaled_delta_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ap_corr_sigma_scaled_delta_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ap_flux_delta_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ap_flux_delta_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ap_flux_delta_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_area_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_area_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_area_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ixx_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ixx_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ixx_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ixy_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ixy_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_ixy_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_iyy_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_iyy_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_iyy_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_sigma_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_sigma_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_sigma_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e1_median_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e1_median_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e1_median_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e1_scatter_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e1_scatter_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e1_scatter_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e2_median_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e2_median_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e2_median_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e2_scatter_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e2_scatter_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_e2_scatter_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_size_median_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_size_median_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_size_median_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_size_scatter_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_size_scatter_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_delta_size_scatter_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_scaled_delta_size_scatter_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_scaled_delta_size_scatter_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_star_scaled_delta_size_scatter_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_trace_radius_delta_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_trace_radius_delta_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "psf_trace_radius_delta_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "seeing_zenith_500nm_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "seeing_zenith_500nm_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "seeing_zenith_500nm_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "seq_num" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "sky_bg_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "sky_bg_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "sky_bg_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "sky_noise_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "sky_noise_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "sky_noise_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "stats_mag_lim_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "stats_mag_lim_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "stats_mag_lim_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "visit_id" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "zero_point_max" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "zero_point_median" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "zero_point_min" from cdb_lsstcomcamsim.visit1_quicklook LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "air_temp" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "airmass" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "altitude" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "altitude_end" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "altitude_start" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "azimuth" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "azimuth_end" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "azimuth_start" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "day_obs" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "dimm_seeing" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "dome_azimuth" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "exp_midpt" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "exp_midpt_mjd" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "exp_time" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "exposure_id" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "humidity" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "img_type" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "obs_end" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "obs_end_mjd" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "obs_start" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "obs_start_mjd" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "pressure" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "s_dec" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "s_ra" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "seq_num" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "sky_rotation" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "target_name" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "vignette" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "vignette_min" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "wind_dir" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "wind_speed" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook
# SELECT "zenith_distance" from cdb_startrackerfast.exposure LIMIT 1
# ERROR: current transaction is aborted, commands ignored until end of transaction block ERROR: permission denied for table visit1_quicklook

# %%
schema_results_table = service.search('SELECT "value" from cdb_lsstcomcamsim.ccdexposure_flexdata LIMIT 1').to_table()
# Out:
# ---------------------------------------------------------------------------
# DALQueryError                             Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 schema_results_table = service.search('SELECT "value" from cdb_lsstcomcamsim.ccdexposure_flexdata LIMIT 1').to_table()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:282, in TAPService.run_sync(self, query, language, maxrec, uploads, **keywords)
#     253 def run_sync(
#     254         self, query, *, language="ADQL", maxrec=None, uploads=None,
#     255         **keywords):
#     256     """
#     257     runs sync query and returns its result
#     258
#    (...)
#     278     TAPResults
#     279     """
#     280     return self.create_query(
#     281         query, language=language, maxrec=maxrec, uploads=uploads,
# --> 282         **keywords).execute()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:1121, in TAPQuery.execute(self)
#    1107 def execute(self):
#    1108     """
#    1109     submit the query and return the results as a TAPResults instance
#    1110
#    (...)
#    1119        for errors parsing the VOTable response
#    1120     """
# -> 1121     return TAPResults(self.execute_votable(), url=self.queryurl, session=self._session)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/adhoc.py:114, in AdhocServiceResultsMixin.__init__(self, votable, url, session)
#     113 def __init__(self, votable, *, url=None, session=None):
# --> 114     super().__init__(votable, url=url, session=session)
#     115     self._adhocservices = list(
#     116         resource for resource in votable.resources
#     117         if resource.type == "meta" and resource.utype == "adhoc:service"
#     118     )
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/query.py:338, in DALResults.__init__(self, votable, url, session)
#     336 self._status = self._findstatus(votable)
#     337 if self._status[0].lower() not in ("ok", "overflow"):
# --> 338     raise DALQueryError(self._status[1], self._status[0], url)
#     340 if self._status[0].lower() == "overflow":
#     341     warn("Partial result set. Potential causes MAXREC, async storage space, etc.",
#     342          category=DALOverflowWarning)
#
# DALQueryError: ERROR: permission denied for table ccdexposure_flexdata

# %%
schema_results_table = get_tap_service("consdbtap").search('SELECT "value" from cdb_lsstcomcamsim.ccdexposure_flexdata LIMIT 1').to_table()
# Out:
# ---------------------------------------------------------------------------
# DALQueryError                             Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 schema_results_table = get_tap_service("consdbtap").search('SELECT "value" from cdb_lsstcomcamsim.ccdexposure_flexdata LIMIT 1').to_table()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:282, in TAPService.run_sync(self, query, language, maxrec, uploads, **keywords)
#     253 def run_sync(
#     254         self, query, *, language="ADQL", maxrec=None, uploads=None,
#     255         **keywords):
#     256     """
#     257     runs sync query and returns its result
#     258
#    (...)
#     278     TAPResults
#     279     """
#     280     return self.create_query(
#     281         query, language=language, maxrec=maxrec, uploads=uploads,
# --> 282         **keywords).execute()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:1121, in TAPQuery.execute(self)
#    1107 def execute(self):
#    1108     """
#    1109     submit the query and return the results as a TAPResults instance
#    1110
#    (...)
#    1119        for errors parsing the VOTable response
#    1120     """
# -> 1121     return TAPResults(self.execute_votable(), url=self.queryurl, session=self._session)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/adhoc.py:114, in AdhocServiceResultsMixin.__init__(self, votable, url, session)
#     113 def __init__(self, votable, *, url=None, session=None):
# --> 114     super().__init__(votable, url=url, session=session)
#     115     self._adhocservices = list(
#     116         resource for resource in votable.resources
#     117         if resource.type == "meta" and resource.utype == "adhoc:service"
#     118     )
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/query.py:338, in DALResults.__init__(self, votable, url, session)
#     336 self._status = self._findstatus(votable)
#     337 if self._status[0].lower() not in ("ok", "overflow"):
# --> 338     raise DALQueryError(self._status[1], self._status[0], url)
#     340 if self._status[0].lower() == "overflow":
#     341     warn("Partial result set. Potential causes MAXREC, async storage space, etc.",
#     342          category=DALOverflowWarning)
#
# DALQueryError: ERROR: permission denied for table ccdexposure_flexdata

# %%
get_tap_service("consdbtap").search('SELECT "value" from cdb_lsstcomcamsim.ccdexposure LIMIT 1').to_table()
# Out:
# ---------------------------------------------------------------------------
# DALQueryError                             Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 get_tap_service("consdbtap").search('SELECT "value" from cdb_lsstcomcamsim.ccdexposure LIMIT 1').to_table()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:282, in TAPService.run_sync(self, query, language, maxrec, uploads, **keywords)
#     253 def run_sync(
#     254         self, query, *, language="ADQL", maxrec=None, uploads=None,
#     255         **keywords):
#     256     """
#     257     runs sync query and returns its result
#     258
#    (...)
#     278     TAPResults
#     279     """
#     280     return self.create_query(
#     281         query, language=language, maxrec=maxrec, uploads=uploads,
# --> 282         **keywords).execute()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:1121, in TAPQuery.execute(self)
#    1107 def execute(self):
#    1108     """
#    1109     submit the query and return the results as a TAPResults instance
#    1110
#    (...)
#    1119        for errors parsing the VOTable response
#    1120     """
# -> 1121     return TAPResults(self.execute_votable(), url=self.queryurl, session=self._session)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/adhoc.py:114, in AdhocServiceResultsMixin.__init__(self, votable, url, session)
#     113 def __init__(self, votable, *, url=None, session=None):
# --> 114     super().__init__(votable, url=url, session=session)
#     115     self._adhocservices = list(
#     116         resource for resource in votable.resources
#     117         if resource.type == "meta" and resource.utype == "adhoc:service"
#     118     )
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/query.py:338, in DALResults.__init__(self, votable, url, session)
#     336 self._status = self._findstatus(votable)
#     337 if self._status[0].lower() not in ("ok", "overflow"):
# --> 338     raise DALQueryError(self._status[1], self._status[0], url)
#     340 if self._status[0].lower() == "overflow":
#     341     warn("Partial result set. Potential causes MAXREC, async storage space, etc.",
#     342          category=DALOverflowWarning)
#
# DALQueryError: validateColumnNonAlias: Column: ["value"] does not exist.

# %%
get_tap_service("consdbtap").search('SELECT "day_obs" from cdb_lsstcomcamsim.ccdexposure LIMIT 1')
# Out:
# ---------------------------------------------------------------------------
# DALQueryError                             Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 get_tap_service("consdbtap").search('SELECT "day_obs" from cdb_lsstcomcamsim.ccdexposure LIMIT 1')
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:282, in TAPService.run_sync(self, query, language, maxrec, uploads, **keywords)
#     253 def run_sync(
#     254         self, query, *, language="ADQL", maxrec=None, uploads=None,
#     255         **keywords):
#     256     """
#     257     runs sync query and returns its result
#     258
#    (...)
#     278     TAPResults
#     279     """
#     280     return self.create_query(
#     281         query, language=language, maxrec=maxrec, uploads=uploads,
# --> 282         **keywords).execute()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/tap.py:1121, in TAPQuery.execute(self)
#    1107 def execute(self):
#    1108     """
#    1109     submit the query and return the results as a TAPResults instance
#    1110
#    (...)
#    1119        for errors parsing the VOTable response
#    1120     """
# -> 1121     return TAPResults(self.execute_votable(), url=self.queryurl, session=self._session)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/adhoc.py:114, in AdhocServiceResultsMixin.__init__(self, votable, url, session)
#     113 def __init__(self, votable, *, url=None, session=None):
# --> 114     super().__init__(votable, url=url, session=session)
#     115     self._adhocservices = list(
#     116         resource for resource in votable.resources
#     117         if resource.type == "meta" and resource.utype == "adhoc:service"
#     118     )
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/site-packages/pyvo/dal/query.py:338, in DALResults.__init__(self, votable, url, session)
#     336 self._status = self._findstatus(votable)
#     337 if self._status[0].lower() not in ("ok", "overflow"):
# --> 338     raise DALQueryError(self._status[1], self._status[0], url)
#     340 if self._status[0].lower() == "overflow":
#     341     warn("Partial result set. Potential causes MAXREC, async storage space, etc.",
#     342          category=DALOverflowWarning)
#
# DALQueryError: ERROR: permission denied for table ccdexposure
